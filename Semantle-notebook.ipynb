# %%
import numpy as np
import random
import gensim.downloader as api
from gensim.models.word2vec import Word2Vec
from gensim.models import KeyedVectors
from nltk import FreqDist, download
from nltk.corpus import brown, stopwords
import nltk
import pandas

# %%
download('brown')
download('stopwords')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/francisfurnelli/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/francisfurnelli/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Generate word list of most common English words
# Load embedding model (Word2Vec)

# %%
frequency_list = FreqDist(word for word in brown.words() if word.islower())
top_20000 = [word for word,_ in frequency_list.most_common(20000)]
top_10000 = [word for word,_ in frequency_list.most_common(10000)]
top_5000 = [word for word,_ in frequency_list.most_common(5000)]
embedding_model = api.load('word2vec-google-news-300')
word_list = [word for word in top_20000 if word in embedding_model]

# %%
stopwords = set(stopwords.words("english"))
print(len(stopwords))
# Out:
# 198

# %% [markdown]
# Create list of Semantle target words (from archive games)

# %%
df = pandas.read_csv("semantle.csv")
target_words=df['answer'].to_list()
print(target_words)
# Out:
# ['forever', 'executive', 'elevator', 'patience', 'overnight', 'belt', 'eager', 'boil', 'favorite', 'candle', 'crush', 'vital', 'patent', 'display', 'most', 'tail', 'latter', 'surgeon', 'monthly', 'consume', 'plea', 'miracle', 'level', 'seek', 'world', 'costly', 'historian', 'appreciation', 'ideological', 'piano', 'spy', 'suitable', 'liver', 'bold', 'value', 'bat', 'selection', 'field', 'surrounding', 'generous', 'speaker', 'manager', 'pork', 'greet', 'track', 'circle', 'area', 'objective', 'assemble', 'pot', 'resist', 'curriculum', 'craft', 'shot', 'rocket', 'cooperate', 'nod', 'ugly', 'newspaper', 'soar', 'principle', 'democratic', 'present', 'vendor', 'direct', 'cooperation', 'athletic', 'absolute', 'surprise', 'asset', 'button', 'bar', 'prevail', 'apple', 'title', 'gathering', 'recruit', 'grateful', 'philosophical', 'horse', 'mother', 'note', 'contribution', 'lend', 'roll', 'gather', 'cliff', 'spill', 'alcohol', 'equality', 'headphones', 'offensive', 'together', 'poem', 'booth', 'grandparent', 'legislator', 'repeatedly', 'speculation', 'job', 'century', 'entitle', 'debate', 'landing', 'match', 'visor', 'poke', 'limited', 'lean', 'forgetful', 'individual', 'commercial', 'active', 'chess', 'company', 'checkers', 'example', 'lighting', 'missing', 'voter', 'painter', 'uncomplicated', 'affair', 'architect', 'bucket', 'ours', 'glass', 'chew', 'seat', 'melting', 'related', 'twist', 'lament', 'elephant', 'slot', 'pitcher', 'preparation', 'efficiency', 'consciousness', 'trainer', 'columnist', 'alike', 'badly', 'wealthy', 'palate', 'tourist', 'taxpayer', 'learn', 'deficit', 'publicity', 'evaluation', 'magnetic', 'retirement', 'discussion', 'overlook', 'after', 'oil', 'difficult', 'inspiration', 'fork', 'brief', 'lesson', 'cheese', 'use', 'telescope', 'step', 'relationship', 'habitat', 'testimony', 'jar', 'achievement', 'terrible', 'insert', 'discount', 'devote', 'safety', 'shrimp', 'accounting', 'container', 'flying', 'tank', 'secular', 'caution', 'elegant', 'terribly', 'invite', 'factory', 'typically', 'adjust', 'instinct', 'clearly', 'theoretical', 'accomplish', 'finally', 'solution', 'sustainable', 'explanation', 'warmth', 'party', 'depth', 'life', 'office', 'cholesterol', 'discrimination', 'enough', 'master', 'parish', 'fashion', 'cute', 'civilian', 'subsequent', 'childhood', 'grasp', 'medication', 'bless', 'under', 'enthusiasm', 'vertical', 'autonomy', 'colony', 'wing', 'shape', 'middle', 'infrastructure', 'math', 'virtually', 'accelerate', 'fare', 'chaos', 'tell', 'clay', 'fabric', 'attention', 'neighboring', 'chest', 'temple', 'dining', 'him', 'processor', 'contrast', 'fly', 'bacteria', 'jury', 'layer', 'commodity', 'sidewalk', 'content', 'trend', 'sustain', 'suffering', 'military', 'merchant', 'traffic', 'steam', 'scent', 'yeah', 'gang', 'convinced', 'smell', 'love', 'effort', 'understand', 'builder', 'instruction', 'puzzle', 'spine', 'whisper', 'negotiation', 'psychology', 'free', 'accessible', 'resolution', 'rare', 'argue', 'barrel', 'stumble', 'soup', 'amendment', 'initial', 'requirement', 'multiple', 'sphere', 'glory', 'investigation', 'reliable', 'design', 'toll', 'immediate', 'where', 'interval', 'paper', 'cooperative', 'success', 'cousin', 'anymore', 'thin', 'internal', 'propose', 'presidential', 'sufficient', 'cloth', 'skilled', 'deliver', 'bind', 'odds', 'galaxy', 'custody', 'eating', 'pool', 'unexpected', 'strain', 'heritage', 'wall', 'concerning', 'combination', 'mill', 'custom', 'quickly', 'cop', 'life', 'equally', 'sail', 'fence', 'confusion', 'maximum', 'bankruptcy', 'bus', 'importance', 'spoon', 'force', 'director', 'correct', 'magnitude', 'supply', 'spending', 'former', 'attract', 'little', 'village', 'human', 'shut', 'finally', 'doll', 'commissioner', 'pass', 'fraud', 'universal', 'mess', 'similar', 'treaty', 'education', 'patience', 'predict', 'resistance', 'finding', 'bishop', 'household', 'brush', 'formal', 'diminish', 'curious', 'few', 'market', 'ensure', 'owner', 'hope', 'cook', 'guitar', 'visit', 'groun ...

# %% [markdown]
# Compute average similarity of each word in words, relative to target words
# i.e. how similar on average is a given word to the target words?

# %%
def compute_avg_sim(words):
    """ Compute the average similarity of each word relative to archive target words"""
    similarity = {}
    for word in words:
        similarity[word] = []
        for target in target_words:
            similarity[word].append(embedding_model.similarity(target, word))
    avg_sim = {word: sum(sim)/len(sim) for word,sim in similarity.items()}
    return avg_sim

# %% [markdown]
# Run experiment to find 50 non-stopword words that are most similar to target words on average
# Note: takes about 6 minutes to run on ~20,000 words and ~1,000 target words

# %%
def starting_words_experiment():
    """ Run experiment to find top 50 words that are most similar to all other words (excluding stopwords) """
    stopwords_removed = [word for word in word_list if word not in stopwords and "'" not in word]
    avg_sim = compute_avg_sim(stopwords_removed)
    key = lambda x: x[1]
    top_50 = sorted(avg_sim.items(), key=key, reverse=True)[:50]
    print(top_50)

# %%
starting_words_experiment()
# Out:
# [('anyway', 0.14740422730095282), ('kind', 0.1458793758603586), ('even', 0.14556949784057424), ('something', 0.14321604931706483), ('sort', 0.14140738599105399), ('actually', 0.1411353638493512), ('really', 0.14093228634735402), ('think', 0.1389849579056979), ('simply', 0.13816469241727197), ('know', 0.13698726146689402), ('certainly', 0.1364448555985316), ('probably', 0.13564050060978053), ('guess', 0.1350873400889817), ('always', 0.1339445571073743), ('whatever', 0.13251194475021166), ('obviously', 0.1313012669583895), ('want', 0.13081291222376357), ('suppose', 0.1306406047859043), ('however', 0.13059699088658525), ('subjective', 0.1301808673811567), ('maybe', 0.13008795968003992), ('never', 0.1290132349607262), ('little', 0.12585410348370438), ('somebody', 0.12526854654524666), ('pretend', 0.1248132956947486), ('get', 0.1244708638114701), ('anything', 0.12443192541580005), ('definitely', 0.12424929543846809), ('like', 0.12408517486341222), ('indeed', 0.12398073668501322), ('though', 0.12379918936488266), ('thing', 0.1237196318154525), ('everything', 0.12360451812144528), ('way', 0.12251405867675677), ('else', 0.1223956430414365), ('sense', 0.12225172356488227), ('see', 0.12201491481238831), ('anymore', 0.12184180540355448), ('understand', 0.12163681821475246), ('sometimes', 0.12156001134384399), ('tell', 0.12146080843897118), ('presume', 0.12124265514795511), ('one', 0.1211035484240904), ('surely', 0.1210829940604991), ('anyhow', 0.12072074694199106), ('merely', 0.12063228206229887), ('feel', 0.12050341486831605), ('perhaps', 0.12045800995058974), ('honestly', 0.12015516053157302), ('sure', 0.11999497414956159)]

# %% [markdown]
# Experiment 2: K-means clustering and Nearest Neighbors
# K-means++ works better because it gets a more even spread across the data
# The idea is to find word clusters that are sufficiently diverse

# %%
from sklearn.cluster import kmeans_plusplus
import numpy as np
from sklearn.neighbors import NearestNeighbors

# %%
def cluster():
    stopwords_removed = [word for word in word_list if word not in stopwords and "'" not in word]
    embeddings = embedding_model[stopwords_removed]
    print(stopwords_removed)
    centers, indices = kmeans_plusplus(embeddings, n_clusters=16, random_state=0)#.fit(embeddings)
    #centers = clustering.centers
    knn = NearestNeighbors(n_neighbors=50, algorithm='auto')
    knn.fit(embeddings)
    for i, vec in enumerate(centers):
        distances, indices = knn.kneighbors(vec.reshape(1, -1))
        for id in indices[0]:
            print(stopwords_removed[id])
        print()
cluster()
# Out:
# ['one', 'would', 'said', 'could', 'time', 'two', 'may', 'first', 'like', 'man', 'made', 'new', 'must', 'also', 'even', 'back', 'years', 'many', 'much', 'way', 'people', 'little', 'make', 'good', 'well', 'work', 'men', 'still', 'see', 'get', 'long', 'world', 'know', 'life', 'might', 'us', 'never', 'year', 'last', 'day', 'came', 'used', 'great', 'go', 'right', 'come', 'take', 'another', 'old', 'use', 'around', 'three', 'state', 'without', 'found', 'place', 'home', 'small', 'thought', 'went', 'say', 'upon', 'got', 'left', 'number', 'part', 'course', 'high', 'since', 'away', 'always', 'fact', 'every', 'water', 'think', 'less', 'enough', 'took', 'put', 'head', 'something', 'hand', 'school', 'told', 'far', 'set', 'almost', 'better', 'public', 'end', 'house', 'night', 'called', 'find', 'knew', 'system', 'going', 'eyes', 'asked', 'however', 'group', 'toward', 'give', 'days', 'point', 'though', 'possible', 'program', 'given', 'present', 'face', 'per', 'side', 'room', 'looked', 'important', 'look', 'order', 'business', 'next', 'things', 'become', 'young', 'nothing', 'later', 'felt', 'social', 'case', 'large', 'rather', 'need', 'form', 'saw', 'often', 'least', 'children', 'along', 'best', 'second', 'several', 'ever', 'seemed', 'early', 'thing', 'four', 'power', 'want', 'mind', 'interest', 'within', 'turned', 'light', 'area', 'done', 'big', 'among', 'problem', 'members', 'country', 'began', 'door', 'general', 'family', 'sense', 'kind', 'development', 'matter', 'whole', 'different', 'war', 'open', 'certain', 'help', 'others', 'human', 'let', 'name', 'means', 'action', 'example', 'gave', 'hands', 'yet', 'feet', 'line', 'taken', 'law', 'past', 'seen', 'across', 'local', 'either', 'government', 'experience', 'quite', 'show', 'car', 'words', 'body', 'history', 'really', 'anything', 'death', 'times', 'period', 'half', 'word', 'together', 'city', 'money', 'held', 'whether', 'cannot', 'information', 'week', 'already', 'political', 'shall', 'white', 'brought', 'making', 'seems', 'real', 'question', 'whose', 'keep', 'today', 'ago', 'moment', 'became', 'tell', 'service', 'known', 'behind', 'result', 'field', 'free', 'five', 'available', 'heard', 'problems', 'study', 'reason', 'sure', 'position', 'change', 'probably', 'job', 'areas', 'boy', 'special', 'individual', 'close', 'seem', 'major', 'wife', 'wanted', 'turn', 'full', 'cost', 'church', 'policy', 'necessary', 'voice', 'clear', 'economic', 'air', 'company', 'true', 'front', 'woman', 'feel', 'able', 'future', 'age', 'provide', 'office', 'community', 'perhaps', 'love', 'effect', 'stood', 'national', 'level', 'girl', 'child', 'control', 'rate', 'total', 'common', 'morning', 'run', 'short', 'following', 'million', 'students', 'evidence', 'sound', 'town', 'force', 'value', 'top', 'believe', 'hard', 'mean', 'land', 'although', 'leave', 'surface', 'type', 'play', 'plan', 'six', 'military', 'situation', 'party', 'process', 'various', 'strong', 'says', 'increase', 'lines', 'started', 'music', 'idea', 'minutes', 'longer', 'personal', 'society', 'tax', 'alone', 'mother', 'near', 'schools', 'outside', 'gone', 'usually', 'months', 'needed', 'center', 'expected', 'kept', 'nature', 'private', 'living', 'century', 'values', 'pressure', 'ground', 'basis', 'view', 'art', 'women', 'greater', 'required', 'call', 'wrote', 'moved', 'cut', 'modern', 'conditions', 'complete', 'road', 'return', 'particular', 'support', 'attention', 'soon', 'else', 'book', 'education', 'live', 'late', 'material', 'lost', 'hours', 'stage', 'costs', 'amount', 'followed', 'single', 'added', 'third', 'except', 'hundred', 'space', 'fire', 'board', 'including', 'coming', 'person', 'heart', 'tried', 'dark', 'pay', 'developed', 'reached', 'miles', 'move', 'feeling', 'recent', 'act', 'read', 'makes', 'dead', 'shown', 'figure', 'simply', 'equipment', 'hope', 'class', 'received', 'taking', 'college', 'basic', 'hold', 'inside', 'everything', 'looking', 'trying', 'sometimes', 'industry', 'picture', 'sort', 'cold', 'data', 'care', 'difficult', 'spirit' ...
# captive
# rhinotracheitis
# unwarrantable
# cu.
# freed
#
# clothed
# dressed
# organdy
# naked
# chinning
#
# flock
# flocked
# rhinotracheitis
# compulsives
# ordo
#
# essays
# essay
# poems
# writings
# poetry
#
# statement
# letter
# report
# saying
# said
#
# alloy
# alloys
# aluminum
# steel
# metallic
#
# stretched
# stretching
# extended
# squeezed
# stretches
#
# sing
# singing
# sang
# sings
# sung
#
# hopelessly
# horribly
# woefully
# utterly
# perpetually
#
# meet
# met
# meets
# meeting
# fulfill
#
# weird
# strange
# crazy
# odd
# scary
#
# learning
# teaching
# learn
# learned
# teach
#
# tube
# tubes
# tappet
# oxygens
# floc
#
# periodic
# periodically
# frequent
# subsequent
# continual
#
# condemn
# denounce
# condemning
# condemned
# criticize
#
# coordinated
# coordinate
# coordinating
# organized
# concerted
